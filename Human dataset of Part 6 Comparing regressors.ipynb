# %% [markdown]
# **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **1. Import libraries**

# %% [markdown]
# Install LazyPredict.&nbsp;
# **Note:** Restart the runtime once LazyPredict is installed. Then run the code **one more time**.

# %%
! pip install lazypredict

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## **2. Load the data set**

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Preprocessed Data/human_acetylcholinesterase_06_bioactivity_data_3_class_pIC50_pubchem_fp.csv')
df
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880  pIC50
# 0              1           1           1  ...             0             0   6.12
# 1              1           1           1  ...             0             0   7.00
# 2              1           1           1  ...             0             0   4.30
# 3              1           1           0  ...             0             0   6.52
# 4              1           1           0  ...             0             0   6.10
# ...          ...         ...         ...  ...           ...           ...    ...
# 5038           1           1           1  ...             0             0   5.00
# 5039           1           1           1  ...             0             0   5.12
# 5040           1           1           1  ...             0             0   5.00
# 5041           1           1           1  ...             0             0   4.81
# 5042           1           1           1  ...             0             0   4.17
#
# ...

# %%
X = df.drop('pIC50', axis=1)
Y = df.pIC50

# %%
# Examine X dimension
X.shape
# Out:
# (5043, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (5043, 140)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=100)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# ...
# 100%|██████████| 42/42 [00:00<00:00, 377217.92it/s]

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                      Adjusted R-Squared  ...  Time Taken
# Model                                                    ...
# DecisionTreeRegressor                              0.87  ...        0.16
# ExtraTreeRegressor                                 0.87  ...        0.18
# ExtraTreesRegressor                                0.87  ...        5.98
# GaussianProcessRegressor                           0.87  ...        5.28
# RandomForestRegressor                              0.84  ...        4.65
# XGBRegressor                                       0.83  ...        1.99
# BaggingRegressor                                   0.82  ...        0.58
# MLPRegressor                                       0.79  ...        6.65
# HistGradientBoostingRegressor                      0.69  ...        2.53
# LGBMRegressor                                      0.69  ...        0.40
# KNeighborsRegressor                                0.65  ...        4.15
# ...

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
# Empty DataFrame
# Columns: [Adjusted R-Squared, R-Squared, RMSE, Time Taken]
# Index: []

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="R-Squared", data=predictions_train)
ax.set(xlim=(0, 1))

plt.savefig("prediction_train.jpg", bbox_inches = 'tight')

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="RMSE", data=predictions_train)
ax.set(xlim=(0, 10))

plt.savefig("prediction_train_RMSE.jpg", bbox_inches = 'tight')

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))

plt.savefig("prediction_train_time_taken.jpg", bbox_inches = 'tight')
