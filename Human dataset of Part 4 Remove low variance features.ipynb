# %% [markdown]
# # **Remove low variance**

# %% [markdown]
# **Mount Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Load the dataset

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Preprocessed Data/human_acetylcholinesterase_06_bioactivity_data_3_class_pIC50_pubchem_fp.csv")

# %%
df
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0              1           1           1  ...             0             0  6.124939
# 1              1           1           1  ...             0             0  7.000000
# 2              1           1           1  ...             0             0  4.301030
# 3              1           1           0  ...             0             0  6.522879
# 4              1           1           0  ...             0             0  6.096910
# ...          ...         ...         ...  ...           ...           ...       ...
# 5038           1           1           1  ...             0             0  5.000000
# 5039           1           1           1  ...             0             0  5.120904
# 5040           1           1           1  ...             0             0  5.000000
# 5041           1           1           1  ...             0             0  4.809668
# ...

# %% [markdown]
# **Input features**

# %%
X = df.drop('pIC50', axis=1)
X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 5038           1           1  ...             0             0
# 5039           1           1  ...             0             0
# 5040           1           1  ...             0             0
# 5041           1           1  ...             0             0
# 5042           1           1  ...             0             0
#
# [5043 rows x 881 columns]

# %% [markdown]
# **Output features**

# %%
Y = df.pIC50
Y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 5038    5.000000
# 5039    5.120904
# 5040    5.000000
# 5041    4.809668
# 5042    4.165579
# Name: pIC50, Length: 5043, dtype: float64

# %% [markdown]
# Examine the data dimension

# %%
X.shape
# Out:
# (5043, 881)

# %%
from sklearn.feature_selection import VarianceThreshold

def remove_low_variance(input_data, threshold=0.1):
    selection = VarianceThreshold(threshold)
    selection.fit(input_data)
    return input_data[input_data.columns[selection.get_support(indices=True)]]

X = remove_low_variance(X, threshold=0.1)
X
# Out:
#       PubchemFP3  PubchemFP12  ...  PubchemFP821  PubchemFP824
# 0              0            1  ...             0             0
# 1              0            1  ...             0             0
# 2              0            1  ...             0             0
# 3              0            1  ...             0             0
# 4              0            0  ...             0             0
# ...          ...          ...  ...           ...           ...
# 5038           0            1  ...             0             0
# 5039           0            1  ...             0             0
# 5040           1            1  ...             0             0
# 5041           0            1  ...             0             1
# 5042           0            1  ...             0             1
#
# [5043 rows x 218 columns]

# %%
#from sklearn.feature_selection import VarianceThreshold
#selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
#X = selection.fit_transform(X)

# %%
X.shape
# Out:
# (5043, 218)

# %%
X
# Out:
#       PubchemFP3  PubchemFP12  ...  PubchemFP821  PubchemFP824
# 0              0            1  ...             0             0
# 1              0            1  ...             0             0
# 2              0            1  ...             0             0
# 3              0            1  ...             0             0
# 4              0            0  ...             0             0
# ...          ...          ...  ...           ...           ...
# 5038           0            1  ...             0             0
# 5039           0            1  ...             0             0
# 5040           1            1  ...             0             0
# 5041           0            1  ...             0             1
# 5042           0            1  ...             0             1
#
# [5043 rows x 218 columns]

# %%
X.to_csv('3_class_preprocessed_low_variance.csv', index = False)

# %%
Y = df.pIC50
Y
# Out:
# 0       6.124939
# 1       7.000000
# 2       4.301030
# 3       6.522879
# 4       6.096910
#           ...
# 5038    5.000000
# 5039    5.120904
# 5040    5.000000
# 5041    4.809668
# 5042    4.165579
# Name: pIC50, Length: 5043, dtype: float64

# %%
Y.to_csv("3_class_pIC50.csv", index=False)
