# %% [markdown]
# # **Download PaDEL Descriptor**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
! wget https://github.com/dataprofessor/bioinformatics/raw/master/padel.sh
# Out:
# --2021-06-17 09:10:34--  https://github.com/dataprofessor/bioinformatics/raw/master/padel.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip [following]
# --2021-06-17 09:10:34--  https://raw.githubusercontent.com/dataprofessor/bioinformatics/master/padel.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25768637 (25M) [application/zip]
# Saving to: ‘padel.zip’
#
# padel.zip           100%[===================>]  24.57M  55.5MB/s    in 0.4s
#
# 2021-06-17 09:10:35 (55.5 MB/s) - ‘padel.zip’ saved [25768637/25768637]
#
# ...

# %%
! unzip padel.zip
# Out:
# Archive:  padel.zip
#    creating: PaDEL-Descriptor/
#   inflating: __MACOSX/._PaDEL-Descriptor
#   inflating: PaDEL-Descriptor/MACCSFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._MACCSFingerprinter.xml
#   inflating: PaDEL-Descriptor/AtomPairs2DFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._AtomPairs2DFingerprinter.xml
#   inflating: PaDEL-Descriptor/EStateFingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._EStateFingerprinter.xml
#   inflating: PaDEL-Descriptor/Fingerprinter.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._Fingerprinter.xml
#   inflating: PaDEL-Descriptor/.DS_Store
#   inflating: __MACOSX/PaDEL-Descriptor/._.DS_Store
#    creating: PaDEL-Descriptor/license/
#   inflating: __MACOSX/PaDEL-Descriptor/._license
#   inflating: PaDEL-Descriptor/KlekotaRothFingerprintCount.xml
#   inflating: __MACOSX/PaDEL-Descriptor/._KlekotaRothFingerprintCount.xml
#   inflating: PaDEL-Descriptor/config
# ...

# %%
import pandas as pd

# %%
df3 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Preprocessed Data/rat/rat_acetylcholinesterase_05_bioactivity_2_class_pIC50.csv')

# %%
df3
# Out:
#       Unnamed: 0 molecule_chembl_id  ... NumHAcceptors     pIC50
# 0              0        CHEMBL15886  ...           3.0  4.000000
# 1              1       CHEMBL556129  ...           1.0  3.698970
# 2              2        CHEMBL15795  ...           0.0  3.585027
# 3              3       CHEMBL276539  ...           0.0  4.221849
# 4              4       CHEMBL278956  ...           1.0  3.698970
# ...          ...                ...  ...           ...       ...
# 1092        1439      CHEMBL4553651  ...           8.0  6.251812
# 1093        1441      CHEMBL4463164  ...           8.0  4.562249
# 1094        1442      CHEMBL4467746  ...           8.0  4.511449
# 1095        1445      CHEMBL4475678  ...           8.0  4.974694
# 1096        1447       CHEMBL231160  ...           8.0  8.809668
#
# [1097 rows x 9 columns]

# %%
selection = ['canonical_smiles','molecule_chembl_id']
df3_selection = df3[selection]
df3_selection.to_csv('molecule.smi', sep='\t', index=False, header=False)

# %%
! cat molecule.smi | head -5
# Out:
# CC[N+](C)(CC)CC(=O)CCN1C(=O)CCC1=O.[I-]	CHEMBL15886
# C[n+]1ccccc1CCC(O)CCl.[I-]	CHEMBL556129
# C[N+](C)(C)CCCCl.[Br-]	CHEMBL15795
# BrCCCCCC[n+]1ccccc1.[Br-]	CHEMBL276539
# CC[N+](C)(CC)CCc1ccncc1.[I-]	CHEMBL278956

# %%
! cat molecule.smi | wc -l
# Out:
# 1097

# %% [markdown]
# # **Calculate fingerprint descriptors**

# %% [markdown]
# Calculate PaDEL descriptors

# %%
! cat padel.sh
# Out:
# java -Xms1G -Xmx1G -Djava.awt.headless=true -jar ./PaDEL-Descriptor/PaDEL-Descriptor.jar -removesalt -standardizenitro -fingerprints -descriptortypes ./PaDEL-Descriptor/PubchemFingerprinter.xml -dir ./ -file descriptors_output.csv

# %%
! bash padel.sh
# Out:
# Processing CHEMBL15886 in molecule.smi (1/1097).
# Processing CHEMBL556129 in molecule.smi (2/1097).
# Processing CHEMBL15795 in molecule.smi (3/1097). Average speed: 2.15 s/mol.
# Processing CHEMBL276539 in molecule.smi (4/1097). Average speed: 1.11 s/mol.
# Processing CHEMBL278956 in molecule.smi (5/1097). Average speed: 0.79 s/mol.
# Processing CHEMBL539116 in molecule.smi (6/1097). Average speed: 0.65 s/mol.
# Processing CHEMBL276538 in molecule.smi (7/1097). Average speed: 0.57 s/mol.
# Processing CHEMBL538102 in molecule.smi (9/1097). Average speed: 0.45 s/mol.
# Processing CHEMBL15822 in molecule.smi (8/1097). Average speed: 0.50 s/mol.
# Processing CHEMBL1159683 in molecule.smi (10/1097). Average speed: 0.42 s/mol.
# Processing CHEMBL539117 in molecule.smi (11/1097). Average speed: 0.39 s/mol.
# Processing CHEMBL53598 in molecule.smi (13/1097). Average speed: 0.36 s/mol.
# Processing CHEMBL53239 in molecule.smi (12/1097). Average speed: 0.39 s/mol.
# ...

# %%
ls -l
# Out:
# total 27176
# -rw-r--r-- 1 root root  1961031 Jun 17 09:15 descriptors_output.csv
# drwx------ 6 root root     4096 Jun 17 09:10 drive/
# drwxr-xr-x 3 root root     4096 Jun 17 09:10 __MACOSX/
# -rw-r--r-- 1 root root    71133 Jun 17 09:10 molecule.smi
# drwxrwxr-x 4 root root     4096 May 30  2020 PaDEL-Descriptor/
# -rw-r--r-- 1 root root      231 Jun 17 09:10 padel.sh
# -rw-r--r-- 1 root root 25768637 Jun 17 09:10 padel.zip
# drwxr-xr-x 1 root root     4096 Jun 15 13:37 sample_data/

# %% [markdown]
# # **Preparing X and Y data matices**

# %% [markdown]
# **X data matrix**

# %%
df3_X = pd.read_csv('descriptors_output.csv')
df3_X
# Out:
#                Name  PubchemFP0  ...  PubchemFP879  PubchemFP880
# 0       CHEMBL15886           1  ...             0             0
# 1      CHEMBL556129           1  ...             0             0
# 2       CHEMBL15795           1  ...             0             0
# 3      CHEMBL276539           1  ...             0             0
# 4      CHEMBL278956           1  ...             0             0
# ...             ...         ...  ...           ...           ...
# 1092  CHEMBL4553651           1  ...             0             0
# 1093  CHEMBL4463164           1  ...             0             0
# 1094  CHEMBL4467746           1  ...             0             0
# 1095   CHEMBL231160           1  ...             0             0
# 1096  CHEMBL4475678           1  ...             0             0
#
# [1097 rows x 882 columns]

# %%
df3_X = df3_X.drop(columns=['Name'])
df3_X
# Out:
#       PubchemFP0  PubchemFP1  ...  PubchemFP879  PubchemFP880
# 0              1           1  ...             0             0
# 1              1           1  ...             0             0
# 2              1           1  ...             0             0
# 3              1           1  ...             0             0
# 4              1           1  ...             0             0
# ...          ...         ...  ...           ...           ...
# 1092           1           1  ...             0             0
# 1093           1           1  ...             0             0
# 1094           1           1  ...             0             0
# 1095           1           1  ...             0             0
# 1096           1           1  ...             0             0
#
# [1097 rows x 881 columns]

# %% [markdown]
# **Y Variable**

# %% [markdown]
# Covert **IC50** to **pIC50**

# %%
df3_Y = df3['pIC50']
df3_Y
# Out:
# 0       4.000000
# 1       3.698970
# 2       3.585027
# 3       4.221849
# 4       3.698970
#           ...
# 1092    6.251812
# 1093    4.562249
# 1094    4.511449
# 1095    4.974694
# 1096    8.809668
# Name: pIC50, Length: 1097, dtype: float64

# %% [markdown]
# Concatenate X and Y variable

# %%
dataset3 = pd.concat([df3_X,df3_Y], axis=1)
dataset3
# Out:
#       PubchemFP0  PubchemFP1  PubchemFP2  ...  PubchemFP879  PubchemFP880     pIC50
# 0              1           1           1  ...             0             0  4.000000
# 1              1           1           0  ...             0             0  3.698970
# 2              1           1           0  ...             0             0  3.585027
# 3              1           1           1  ...             0             0  4.221849
# 4              1           1           1  ...             0             0  3.698970
# ...          ...         ...         ...  ...           ...           ...       ...
# 1092           1           1           1  ...             0             0  6.251812
# 1093           1           1           1  ...             0             0  4.562249
# 1094           1           1           1  ...             0             0  4.511449
# 1095           1           1           1  ...             0             0  4.974694
# ...

# %%
dataset3.to_csv('rat_acetylcholinesterase_06_bioactivity_data_2_class_pIC50_pubchem_fp.csv', index=False)
